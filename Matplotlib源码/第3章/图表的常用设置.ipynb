# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y,color='r',linestyle='-.') # 点

y=[10,15,20,25,30]
plt.plot(x,y,color='b',linestyle='--') # 双划线

y=[10,13,16,19,22]
plt.plot(x,y,color='g',linestyle=':')# 虚线

y=[10,18,26,34,42]
plt.plot(x,y,color='pink',linestyle='-')# 实线

plt.show()

# %%
# 散点图
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,10,6,7,17]
plt.plot(x,y,'r*')
plt.show()

# %%
# 绘制未来15天天气预报的折线图
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
df=pd.read_excel('未来15天天天气报.xlsx')
x=df['日期']
y=df['温度']
plt.plot(x,y,marker='o',color='r',mfc='w') #markerfacecolor简写mfc
plt.show()

# %%
# 设置画布的颜色
# 绘制未来15天天气预报的折线图
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
df=pd.read_excel('未来15天天天气报.xlsx')

plt.figure(facecolor='yellow',figsize=(10,6))

x=df['日期']
y=df['温度']
plt.plot(x,y,marker='o',color='r',mfc='w') #markerfacecolor简写mfc
plt.show()

# %%
# 设置坐标轴的标题
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
df=pd.read_excel('未来15天天天气报.xlsx')

# 用于处理中文
plt.rcParams['font.sans-serif']=['SimHei']
plt.figure(figsize=(10,6))

x=df['日期']
y=df['温度']

plt.xlabel('2021年五一')  # x轴的标题
plt.ylabel('室外温度')    #y轴的标题
plt.plot(x,y,marker='o',color='r',mfc='w') #markerfacecolor简写mfc
plt.show()

# %%
# 设置坐标轴的刻度
import matplotlib.pyplot as plt
import random
x=[i for i in range(1,11)] # 列表生成式
y=[random.randint(1,10) for _ in range(10)]

plt.plot(x,y,marker='o',mfc='w')

month=[str(i)+'月' for i in range(1,11)]

plt.xticks(range(1,11),month) # # 设置x轴坐标轴刻度
plt.yticks(range(1,11)) # 设置y轴坐标轴刻度

plt.xlim(1,10) # 设置坐标轴范围
plt.ylim(1,20)


plt.show()

# %%
# 设置坐标轴的刻度
import matplotlib.pyplot as plt
import random
x=[i for i in range(1,11)] # 列表生成式
y=[random.randint(1,10) for _ in range(10)]

plt.plot(x,y,marker='o',mfc='w')

month=[str(i)+'月' for i in range(1,11)]

plt.xticks(range(1,11),month) # # 设置x轴坐标轴刻度
plt.yticks(range(1,11)) # 设置y轴坐标轴刻度


#plt.grid(color='r',linestyle='--',linewidth='1')
#plt.grid(color='r',linestyle='--',linewidth='1',axis='x')# 隐藏x轴网格线

plt.grid(color='0.5',linestyle='--',linewidth='1',axis='y')# 隐藏y轴网格线
plt.show()

# %%
# 添加文本标签
import matplotlib.pyplot as plt
import random
x=[i for i in range(1,11)] # 列表生成式
y=[random.randint(1,10) for _ in range(10)]

plt.plot(x,y,marker='o',mfc='w')

month=[str(i)+'月' for i in range(1,11)]

plt.xticks(range(1,11),month) # # 设置x轴坐标轴刻度
plt.yticks(range(1,11)) # 设置y轴坐标轴刻度

# 添加文本标签
for a,b in zip(x,y):
    plt.text(a,b,b,ha='center',va='bottom',fontsize=15,color='r')
    
# 添加图表的标题
plt.title('测试练习折线图',fontsize=18)

# 添加图例
plt.legend(('销售次数',))
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[10,42,35,46,7,34]
plt.plot(x,y,marker='o')
for a,b in zip(x,y):
    plt.text(a,b,b,ha='center',va='bottom',fontsize=12,color='r')
# 添加文本注释

plt.annotate('最大数',xy=(4,46),xytext=(5,46),arrowprops=dict(facecolor='r',shrink=0.05))
plt.show()

# %%
# 图表与画布边缘的间距
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[10,42,35,46,7,34]
plt.plot(x,y,marker='o')
for a,b in zip(x,y):
    plt.text(a,b,b,ha='center',va='bottom',fontsize=12,color='r')
# 添加文本注释

plt.annotate('最大数',xy=(4,46),xytext=(5,46),arrowprops=dict(facecolor='r',shrink=0.05))


# 设置间距
plt.subplots_adjust(left=0.2,right=0.9,top=0.9,bottom=0.2)
plt.show()

# %%
# 设置 坐标轴刻度线
# 图表与画布边缘的间距
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[10,42,35,46,7,34]
plt.plot(x,y,marker='o')
for a,b in zip(x,y):
    plt.text(a,b,b,ha='center',va='bottom',fontsize=12,color='r')
# 添加文本注释

plt.annotate('最大数',xy=(4,46),xytext=(5,46),arrowprops=dict(facecolor='r',shrink=0.05))


# 设置间距
plt.subplots_adjust(left=0.2,right=0.9,top=0.9,bottom=0.2)

# 设置是否显示坐标轴刻度线

#plt.tick_params(bottom=False,left=True,right=True,top=True) # 底则不显示

# 设置坐标轴刻度线显示的方向
plt.rcParams['xtick.direction']='in'
plt.rcParams['ytick.direction']='out'

plt.show()
