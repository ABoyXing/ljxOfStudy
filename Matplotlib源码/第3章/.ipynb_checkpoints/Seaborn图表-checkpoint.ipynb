# %%
#绘制简单的柱状图
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('white') # 设置风格样式

#plt.figure()
x=[1,2,3,4,5]
y=[90,54,34,5,45]
sns.barplot(x,y)

plt.show()

# %%
# 常用图表的绘制--折线图
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=pd.read_excel(r'C:\Users\厉佳星\PycharmProjects\pythonProject2\Matplotlib源码\第3章\成绩表.xlsx')

sns.relplot(x='姓名',y='数学',kind='line',data=df)
sns.relplot(x='姓名', y='数学', kind='scatter', data=df)

plt.xticks(df['姓名'],rotation=45)

plt.show()

# %%
# 常用图表的绘制--折线图
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=pd.read_excel('成绩表.xlsx')

sns.lineplot(x='姓名',y='数学',data=df)

plt.xticks(df['姓名'],rotation=45)

plt.show()

# %%
# 常用图表的绘制--折线图(多折线图)
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=pd.read_excel('成绩表.xlsx')

df1=df[['数学','语文','英语']]

dfs=[df1['数学'],df1['语文'],df1['英语']]

sns.lineplot(data=dfs)

#plt.xticks(df['姓名'],rotation=45)

plt.show()

# %%
# 绘制直方图
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=pd.read_excel('data2.xls')

data=df[['得分']] # 准备数据

sns.distplot(data,rug=True)

plt.show()

# %%
#绘制条形图

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=pd.read_excel('成绩表.xlsx')

#条形图
sns.barplot(x='姓名',y='数学',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 14
#      11 plt.rcParams['font.sans-serif']=['SimHei']
#      13 # 读取数据
# ---> 14 df=pd.read_excel('成绩表.xlsx')
#      16 #条形图
#      17 sns.barplot(x='姓名',y='数学',data=df)
#
# File D:\Python\python3.10.11\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
# 散点图

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 

# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=sns.load_dataset('tips') #关于小费数据集，是seaborn自带的

sns.relplot(x='total_bill',y='tip',data=df,color='r')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File D:\Python\python3.10.11\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File D:\Python\python3.10.11\lib\http\client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File D:\Python\python3.10.11\lib\http\client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# ...

# %%
# 绘制线性回归模型

import matplotlib.pyplot as plt
import seaborn as sns


# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=sns.load_dataset('tips') #关于小费数据集，是seaborn自带的

#绘制
sns.lmplot(x='total_bill',y='tip',data=df)

plt.show()

# %%
# 箱形图
import matplotlib.pyplot as plt
import seaborn as sns


# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=sns.load_dataset('tips') #关于小费数据集，是seaborn自带的

#绘制
sns.boxplot(x='day',y='total_bill',hue='time',data=df)

plt.show()

# %%
# 绘制核密度图
# 鸢尾花
import matplotlib.pyplot as plt
import seaborn as sns


# 设置样式
sns.set_style('darkgrid')
# 解决中文乱码

plt.rcParams['font.sans-serif']=['SimHei']

# 读取数据
df=sns.load_dataset('iris') #是seaborn自带的

# # 绘制
# sns.kdeplot(df['sepal_width'],shade=True,color='r')
# 
# sns.kdeplot(df['sepal_length'],shade=True,color='b')
# plt.show()
# df
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File D:\Python\python3.10.11\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File D:\Python\python3.10.11\lib\http\client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File D:\Python\python3.10.11\lib\http\client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# ...
